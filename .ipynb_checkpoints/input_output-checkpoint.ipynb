# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from scipy.io import wavfile
import ttslearn
import librosa.display

# %%
# !pip install ttslearn
# Out:
# Collecting ttslearn
#   Downloading ttslearn-0.2.2.tar.gz (295 kB)
#      -------------------------------------- 295.2/295.2 kB 6.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.19 in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (1.26.3)
# Requirement already satisfied: scipy in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (1.11.3)
# Requirement already satisfied: torch>=1.0.0 in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (2.2.0)
# Collecting pysptk (from ttslearn)
#   Downloading pysptk-0.2.2.tar.gz (421 kB)
#      ------------------------------------- 421.3/421.3 kB 12.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nnmnkwii>=0.0.23 (from ttslearn)
#   Downloading nnmnkwii-0.1.2.tar.gz (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 18.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyworld (from ttslearn)
#   Downloading pyworld-0.3.4-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: librosa>=0.8.1 in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (0.10.1)
# Requirement already satisfied: tqdm in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (4.64.1)
# Requirement already satisfied: joblib in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (1.3.2)
# Collecting hydra-core>=1.1.0 (from ttslearn)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      -------------------------------------- 154.5/154.5 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pyopenjtalk>=0.1.0 in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (0.3.3)
# Requirement already satisfied: matplotlib>=1.5 in c:\users\kanat\anaconda3\lib\site-packages (from ttslearn) (3.5.2)
# Collecting parallel-wavegan>=0.5.1 (from ttslearn)
#   Downloading parallel_wavegan-0.6.1.tar.gz (100 kB)
#      ---------------------------------------- 100.2/100.2 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.1.0->ttslearn)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.5/79.5 kB ? eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1.0->ttslearn)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      -------------------------------------- 117.0/117.0 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: packaging in c:\users\kanat\anaconda3\lib\site-packages (from hydra-core>=1.1.0->ttslearn) (21.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (1.0.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\kanat\anaconda3\lib\site-packages (from librosa>=0.8.1->ttslearn) (1.0.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kanat\anaconda3\lib\site-packages (from matplotlib>=1.5->ttslearn) (2.8.2)
# Requirement already satisfied: cython>=0.28.0 in c:\users\kanat\anaconda3\lib\site-packages (from nnmnkwii>=0.0.23->ttslearn) (0.29.32)
# Collecting fastdtw (from nnmnkwii>=0.0.23->ttslearn)
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      -------------------------------------- 133.4/133.4 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools>=38.5.1 in c:\users\kanat\anaconda3\lib\site-packages (from parallel-wavegan>=0.5.1->ttslearn) (63.4.1)
# Collecting tensorboardX>=1.8 (from parallel-wavegan>=0.5.1->ttslearn)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: PyYAML>=3.12 in c:\users\kanat\anaconda3\lib\site-packages (from parallel-wavegan>=0.5.1->ttslearn) (6.0)
# Collecting kaldiio>=2.14.1 (from parallel-wavegan>=0.5.1->ttslearn)
#   Downloading kaldiio-2.18.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kanat\anaconda3\lib\site-packages (from parallel-wavegan>=0.5.1->ttslearn) (3.7.0)
# Collecting yq>=2.10.0 (from parallel-wavegan>=0.5.1->ttslearn)
#   Downloading yq-3.2.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting gdown (from parallel-wavegan>=0.5.1->ttslearn)
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: filelock in c:\users\kanat\anaconda3\lib\site-packages (from parallel-wavegan>=0.5.1->ttslearn) (3.6.0)
# Requirement already satisfied: six in c:\users\kanat\anaconda3\lib\site-packages (from pyopenjtalk>=0.1.0->ttslearn) (1.16.0)
# Requirement already satisfied: sympy in c:\users\kanat\anaconda3\lib\site-packages (from torch>=1.0.0->ttslearn) (1.10.1)
# Requirement already satisfied: networkx in c:\users\kanat\anaconda3\lib\site-packages (from torch>=1.0.0->ttslearn) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\kanat\anaconda3\lib\site-packages (from torch>=1.0.0->ttslearn) (2.11.3)
# Requirement already satisfied: fsspec in c:\users\kanat\anaconda3\lib\site-packages (from torch>=1.0.0->ttslearn) (2023.10.0)
# Requirement already satisfied: colorama in c:\users\kanat\anaconda3\lib\site-packages (from tqdm->ttslearn) (0.4.5)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\kanat\anaconda3\lib\site-packages (from numba>=0.51.0->librosa>=0.8.1->ttslearn) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\kanat\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.8.1->ttslearn) (2.5.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\kanat\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.8.1->ttslearn) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kanat\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa>=0.8.1->ttslearn) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\kanat\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa>=0.8.1->ttslearn) (1.15.1)
# Requirement already satisfied: protobuf>=3.20 in c:\users\kanat\anaconda3\lib\site-packages (from tensorboardX>=1.8->parallel-wavegan>=0.5.1->ttslearn) (3.20.3)
# Collecting xmltodict>=0.11.0 (from yq>=2.10.0->parallel-wavegan>=0.5.1->ttslearn)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting tomlkit>=0.11.6 (from yq>=2.10.0->parallel-wavegan>=0.5.1->ttslearn)
#   Downloading tomlkit-0.12.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting argcomplete>=1.8.1 (from yq>=2.10.0->parallel-wavegan>=0.5.1->ttslearn)
#   Downloading argcomplete-3.2.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\kanat\anaconda3\lib\site-packages (from gdown->parallel-wavegan>=0.5.1->ttslearn) (4.11.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kanat\anaconda3\lib\site-packages (from jinja2->torch>=1.0.0->ttslearn) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kanat\anaconda3\lib\site-packages (from sympy->torch>=1.0.0->ttslearn) (1.2.1)
# Requirement already satisfied: pycparser in c:\users\kanat\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.8.1->ttslearn) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kanat\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->ttslearn) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kanat\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->ttslearn) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kanat\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->ttslearn) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kanat\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->ttslearn) (2022.9.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kanat\anaconda3\lib\site-packages (from beautifulsoup4->gdown->parallel-wavegan>=0.5.1->ttslearn) (2.3.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\kanat\anaconda3\lib\site-packages (from requests[socks]->gdown->parallel-wavegan>=0.5.1->ttslearn) (1.7.1)
# Downloading pyworld-0.3.4-cp39-cp39-win_amd64.whl (224 kB)
#    --------------------------------------- 225.0/225.0 kB 14.3 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
# Downloading yq-3.2.3-py3-none-any.whl (17 kB)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Downloading argcomplete-3.2.2-py3-none-any.whl (42 kB)
#    ---------------------------------------- 42.3/42.3 kB ? eta 0:00:00
# Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Building wheels for collected packages: ttslearn, antlr4-python3-runtime, nnmnkwii, parallel-wavegan, pysptk, fastdtw
#   Building wheel for ttslearn (pyproject.toml): started
#   Building wheel for ttslearn (pyproject.toml): finished with status 'done'
#   Created wheel for ttslearn: filename=ttslearn-0.2.2-py3-none-any.whl size=305019 sha256=9ed71e36410b3241ca09551ff60a44f7196dbdcc0e6aaec15367ba36c3eee557
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\a6\1c\09\14d3cb484f7d4eeb9e0bedb97b0c41e86b268c683050a6f9ad
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144566 sha256=ffcea0f29e72d360fd92e8e91ec050a4cb7137e4b533644833c5f127d1399005
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\23\cf\80\f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for nnmnkwii (pyproject.toml): started
#   Building wheel for nnmnkwii (pyproject.toml): finished with status 'done'
#   Created wheel for nnmnkwii: filename=nnmnkwii-0.1.2-cp39-cp39-win_amd64.whl size=1902801 sha256=f42a24025afe4eee5d762ed23854e0ed4bb8f633fee3a3299378974d42cf3ab6
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\03\a1\23\7297c4c8eacb20d5bc8a60593fc5f8da2ce4c6dedfa5c61f17
#   Building wheel for parallel-wavegan (setup.py): started
#   Building wheel for parallel-wavegan (setup.py): finished with status 'done'
#   Created wheel for parallel-wavegan: filename=parallel_wavegan-0.6.1-py3-none-any.whl size=106238 sha256=053277932a64b78da4d42b3416f71c2f6943ec4e032b96c15da43a3fc07ba3f4
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\b6\6e\46\9108527effe1c7e5a28acd8a3233130c2fc3320c336e45d9f8
#   Building wheel for pysptk (pyproject.toml): started
#   Building wheel for pysptk (pyproject.toml): finished with status 'done'
#   Created wheel for pysptk: filename=pysptk-0.2.2-cp39-cp39-win_amd64.whl size=334716 sha256=e921f216f4c30e621406540de08540dd64034d14a2b554f08cfdfb828595d0e0
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\7f\93\63\9dcdec0ab6de7a89e24af4e08a2d9c60be0d9c01e67c063d5d
#   Building wheel for fastdtw (setup.py): started
#   Building wheel for fastdtw (setup.py): finished with status 'done'
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-py3-none-any.whl size=3566 sha256=444b6adb81ec0e0834879e7056f495113c1726c1c6bd3f4b1b43f065ac5f445b
#   Stored in directory: c:\users\kanat\appdata\local\pip\cache\wheels\1f\a1\63\bfd0fddb5bf0b59f564872e29272cee8a2de0cd745d88fede5
# Successfully built ttslearn antlr4-python3-runtime nnmnkwii parallel-wavegan pysptk fastdtw
# Installing collected packages: antlr4-python3-runtime, xmltodict, tomlkit, pyworld, omegaconf, kaldiio, fastdtw, argcomplete, yq, tensorboardX, pysptk, hydra-core, nnmnkwii, gdown, parallel-wavegan, ttslearn
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
# Successfully installed antlr4-python3-runtime-4.9.3 argcomplete-3.2.2 fastdtw-0.3.4 gdown-5.1.0 hydra-core-1.3.2 kaldiio-2.18.0 nnmnkwii-0.1.2 omegaconf-2.3.0 parallel-wavegan-0.6.1 pysptk-0.2.2 pyworld-0.3.4 tensorboardX-2.6.2.2 tomlkit-0.12.3 ttslearn-0.2.2 xmltodict-0.13.0 yq-3.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.

# %%
from ttslearn.dnntts import DNNTTS
from IPython.display import Audio

# %%
sr, wav = wavfile.read(ttslearn.util.example_audio_file())
fig, ax = plt.subplots(figsize=(8, 2))
librosa.display.waveshow(wav.astype(np.float32), sr=sr)

# %%
import pyaudio

# 音声のパラメータ
RATE = 2**12 # サンプリングレート
CHUNK = 2**14 # チャンクサイズ
FORMAT = pyaudio.paInt16 # フォーマット
CHANNELS = 1 # チャンネル数

# pyaudioのインスタンスを作成
p = pyaudio.PyAudio()

# 入力用のデバイスのインデックス番号
input_device_index = 0
# 出力用のデバイスのインデックス番号
output_device_index = 1

# 入力用のストリームを開く
stream_in = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                  )

# 出力用のストリームを開く
stream_out = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                output=True,
                   )


in_data = stream_in.read(CHUNK)
# 出力用のストリームに書き込む

# %%
output_path = "./output.wav"
wf = wave.open(output_path, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(in_data)
wf.close()
